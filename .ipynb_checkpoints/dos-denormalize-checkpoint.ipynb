# %%
import pandas as pd
import os

# %%
dos_csv = os.path.join('data', 'Other Companies.csv')

# %%
df = pd.read_csv(dos_csv)

# %%
df = df[['Company Trimmed', 'ParentCompany']]

# %%
def denormalizeGparents(df, degrees):
    output = df.copy()
    gencounter = 1
    while(degrees > 1):
        df2 = df.copy()
        gxparent = 'g' + str(gencounter) + 'parent'
        df2.columns=[output.columns[-1], gxparent]
        output = output.merge(df2, how='left', on=output.columns[-1])
        degrees-=1
        gencounter +=1
    return output

# %%
denormalizeGparents(df,5).to_csv(os.path.join('data', 'DOS_g5parents.csv'), index=False)

# %%
titanagro_g5_df = denormalizeGparents(df,5)
titanagro_g5_df['is_gx_child'] = titanagrog5_df.apply(lambda row: 'TITAN - AGRO LIMITED COMPANY' in row.values, axis=1)

titanagro_parents = titanagro_g5_df[titanagro_g5_df['Company Trimmed'] == 'TITAN - AGRO LIMITED COMPANY']
titanagro_parents = titanagro_parents.drop('is_gx_child', axis=1).values.tolist()
titanagro_parents = [company for row in titanagro_parents for company in row]
titanagro_parents = list(set(titanagro_parents))
print(titanagro_parents)

titanagro_g5_df['is_gx_parent'] = titanagro_g5_df['Company Trimmed'].apply(lambda x: x in titanagro_parents)
titanagro_g5_df['titanagro_g5'] = titanagro_g5_df['is_gx_child'] | titanagro_g5_df['is_gx_parent']
titanagro_g5_df
# Out:
# [nan, 'SURGUTNEFTEGASBANK JSC', 'TRANSOIL SNG LIMITED COMPANY', 'OAO SURGUTNEFTEGAS', 'JOINT-STOCK LIMITED COMPANY ZEST', 'BANK ROSSIYA', 'MAPLES SA', 'PUBLICHNOE AKTSIONERNOE OBSCHESTVO OMSKIY KAUCHUK', 'LIMITED LIABILITY COMPANY SURGUT CENTRAL DEPOSITARY', 'INVESTKHIMPROM', 'TITAN - AGRO LIMITED COMPANY', 'GROUP OF COMPANIES TITAN JOINT STOCK COMPANY']
#                                         Company Trimmed  \
# 0                                             MAPLES SA
# 1                          TRANSOIL SNG LIMITED COMPANY
# 2                                          BANK ROSSIYA
# 3          GROUP OF COMPANIES TITAN JOINT STOCK COMPANY
# 4          GROUP OF COMPANIES TITAN JOINT STOCK COMPANY
# 5          GROUP OF COMPANIES TITAN JOINT STOCK COMPANY
# 6          GROUP OF COMPANIES TITAN JOINT STOCK COMPANY
# 7          GROUP OF COMPANIES TITAN JOINT STOCK COMPANY
# 8          GROUP OF COMPANIES TITAN JOINT STOCK COMPANY
# 9          GROUP OF COMPANIES TITAN JOINT STOCK COMPANY
# ...

# %%
titanagro_g5_df.to_csv(os.path.join('data', 'DOS_titanagro_g5.csv'), index=False)
